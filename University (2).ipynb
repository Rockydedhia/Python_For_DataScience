# %%
import pandas as pd


st=pd.read_csv("Studentlist.csv")
qz1=pd.read_csv('quiz1.csv')
qz2=pd.read_csv("quiz2.csv")

# %%
st
# Out:
#       enrollmentnumber          admn           studentname  studentEmail
# 0           1613101016  16SCSE101757         AAYUSH  TYAGI           NaN
# 1           1613101026  16SCSE101415              ABHISHEK           NaN
# 2           1613101051  16SCSE101222          ADITI  SINGH           NaN
# 3           1613101054  16SCSE101220        ADITYA  MANKAR           NaN
# 4           1613101079  16SCSE101085         AKASH  KANSAL           NaN
# ...                ...           ...                   ...           ...
# 1012        1613106007  16SCSE106008         PARTH  SHUKLA           NaN
# 1013        1613106009  16SCSE106003         ROBIN  SHARMA           NaN
# 1014        1613106010  16SCSE106005  SHITIKANT  PRIYANSHU           NaN
# 1015        1613106011  16SCSE106013      SHREYANSH  KUMAR           NaN
# 1016        1613106013  16SCSE106012     SWARNIM  TRIPATHI           NaN
#
# [1017 rows x 4 columns]

# %%
st=st.drop(columns=['enrollmentnumber', 'admn','studentEmail'])

# %%
st
# Out:
#                studentname
# 0            AAYUSH  TYAGI
# 1                 ABHISHEK
# 2             ADITI  SINGH
# 3           ADITYA  MANKAR
# 4            AKASH  KANSAL
# ...                    ...
# 1012         PARTH  SHUKLA
# 1013         ROBIN  SHARMA
# 1014  SHITIKANT  PRIYANSHU
# 1015      SHREYANSH  KUMAR
# 1016     SWARNIM  TRIPATHI
#
# [1017 rows x 1 columns]

# %%
qz1
# Out:
#              Surname            Firstname ID number Institution Department  \
# 0         16BTCSES11      SIDDHANT  GUPTA       NaN         NaN        NaN
# 1         16BTCSES11        ARPIT  SHARMA       NaN         NaN        NaN
# 2         16BTCSES11        VISHAL  SINGH       NaN         NaN        NaN
# 3         16BTCSES11         AKASH  YADAV       NaN         NaN        NaN
# 4         16BTCSES11       MANISH  SAHANI       NaN         NaN        NaN
# ..               ...                  ...       ...         ...        ...
# 655        16BTCSES8  ADITYA PRATAP SINGH       NaN         NaN        NaN
# 656        16BTCSES4        Ankita  Singh       NaN         NaN        NaN
# 657        16BTCSES2         UTTAM  KUMAR       NaN         NaN        NaN
# 658        16BTCSES8          SHREY  JAIN       NaN         NaN        NaN
# 659  Overall average                  NaN       NaN         NaN        NaN
#
#                              Email address     State        Started on  \
# 0                                      NaN  Finished  08-02-2019 09:57
# 1                                      NaN  Finished  08-02-2019 09:57
# 2                                      NaN  Finished  08-02-2019 09:57
# 3                                      NaN  Finished  08-02-2019 09:57
# 4                                      NaN  Finished  08-02-2019 09:57
# ..                                     ...       ...               ...
# 655                                    NaN  Finished  06-03-2019 07:10
# 656                                    NaN  Finished  06-03-2019 07:49
# 657  uttamkumar@galgotiasuniversity.edu.in  Finished  06-03-2019 07:58
# 658  shrey.jain@galgotiasuniversity.edu.in  Finished  06-03-2019 08:05
# 659                                    NaN       NaN               NaN
#
#             Completed        Time taken Grade/10.00
# 0    08-02-2019 10:11     14 mins 1 sec           4
# 1    08-02-2019 10:11    14 mins 5 secs           5
# 2    14-02-2019 10:10            6 days           7
# 3    14-02-2019 12:03    6 days 2 hours           9
# 4    08-02-2019 23:09  13 hours 11 mins           7
# ..                ...               ...         ...
# 655  06-03-2019 07:18    7 mins 16 secs           2
# 656  06-03-2019 07:51    2 mins 22 secs           2
# 657  06-03-2019 08:14   16 mins 12 secs           4
# 658  06-03-2019 08:10    5 mins 23 secs           4
# 659               NaN               NaN         7.4
#
# [660 rows x 11 columns]

# %%
qz1
# Out:
#              Surname            Firstname ID number Institution Department  \
# 0         16BTCSES11      SIDDHANT  GUPTA       NaN         NaN        NaN
# 1         16BTCSES11        ARPIT  SHARMA       NaN         NaN        NaN
# 2         16BTCSES11        VISHAL  SINGH       NaN         NaN        NaN
# 3         16BTCSES11         AKASH  YADAV       NaN         NaN        NaN
# 4         16BTCSES11       MANISH  SAHANI       NaN         NaN        NaN
# ..               ...                  ...       ...         ...        ...
# 655        16BTCSES8  ADITYA PRATAP SINGH       NaN         NaN        NaN
# 656        16BTCSES4        Ankita  Singh       NaN         NaN        NaN
# 657        16BTCSES2         UTTAM  KUMAR       NaN         NaN        NaN
# 658        16BTCSES8          SHREY  JAIN       NaN         NaN        NaN
# 659  Overall average                  NaN       NaN         NaN        NaN
#
#                              Email address     State        Started on  \
# 0                                      NaN  Finished  08-02-2019 09:57
# 1                                      NaN  Finished  08-02-2019 09:57
# 2                                      NaN  Finished  08-02-2019 09:57
# 3                                      NaN  Finished  08-02-2019 09:57
# 4                                      NaN  Finished  08-02-2019 09:57
# ..                                     ...       ...               ...
# 655                                    NaN  Finished  06-03-2019 07:10
# 656                                    NaN  Finished  06-03-2019 07:49
# 657  uttamkumar@galgotiasuniversity.edu.in  Finished  06-03-2019 07:58
# 658  shrey.jain@galgotiasuniversity.edu.in  Finished  06-03-2019 08:05
# 659                                    NaN       NaN               NaN
#
#             Completed        Time taken Grade/10.00
# 0    08-02-2019 10:11     14 mins 1 sec           4
# 1    08-02-2019 10:11    14 mins 5 secs           5
# 2    14-02-2019 10:10            6 days           7
# 3    14-02-2019 12:03    6 days 2 hours           9
# 4    08-02-2019 23:09  13 hours 11 mins           7
# ..                ...               ...         ...
# 655  06-03-2019 07:18    7 mins 16 secs           2
# 656  06-03-2019 07:51    2 mins 22 secs           2
# 657  06-03-2019 08:14   16 mins 12 secs           4
# 658  06-03-2019 08:10    5 mins 23 secs           4
# 659               NaN               NaN         7.4
#
# [660 rows x 11 columns]

# %%
qz1=qz1.drop(columns=['Surname', 'ID number','Institution','Department','Email address','State','Started on','Completed','Time taken'])

# %%
qz1
# Out:
#                Firstname Grade/10.00
# 0        SIDDHANT  GUPTA           4
# 1          ARPIT  SHARMA           5
# 2          VISHAL  SINGH           7
# 3           AKASH  YADAV           9
# 4         MANISH  SAHANI           7
# ..                   ...         ...
# 655  ADITYA PRATAP SINGH           2
# 656        Ankita  Singh           2
# 657         UTTAM  KUMAR           4
# 658          SHREY  JAIN           4
# 659                  NaN         7.4
#
# [660 rows x 2 columns]

# %%
qz2=qz2.drop(columns=['Surname', 'ID number','Institution','Department','Email address','State','Started on','Completed','Time taken'])

# %%
qz2
# Out:
#                 Firstname Grade/10.00
# 0       VEER SINGH GURJAR           4
# 1          PRANSHU  VERMA          10
# 2            EJAZ  BAKHSH           4
# 3              MOHD  FAIZ          10
# 4            ANISH  SINGH          10
# ..                    ...         ...
# 676  SANJEEV KUMAR PANDEY          10
# 677        UTKARSH  GUPTA          10
# 678          GAURAV  SAHU          10
# 679        MAYANK  DHAWAN          10
# 680                   NaN        8.29
#
# [681 rows x 2 columns]

# %%
quiz1Drade=pd.merge(st,qz1,left_on='studentname',right_on='Firstname')

# %%
quiz1Drade
# Out:
#                studentname              Firstname Grade/10.00
# 0            AAYUSH  TYAGI          AAYUSH  TYAGI           5
# 1                 ABHISHEK               ABHISHEK           7
# 2             ADITI  SINGH           ADITI  SINGH           5
# 3           ADITYA  MANKAR         ADITYA  MANKAR           7
# 4             Aman  Pandey           Aman  Pandey           5
# ..                     ...                    ...         ...
# 652           VINOD  KUMAR           VINOD  KUMAR           4
# 653           Akash  Kumar           Akash  Kumar           7
# 654  AVINASH KUMAR JAISWAL  AVINASH KUMAR JAISWAL          10
# 655           MAYANK  JAIN           MAYANK  JAIN           8
# 656          ROBIN  SHARMA          ROBIN  SHARMA           7
#
# [657 rows x 3 columns]

# %%
quiz1Drade=quiz1Drade.drop(columns=['Firstname'])

# %%
quiz1Drade
# Out:
#                studentname Grade/10.00
# 0            AAYUSH  TYAGI           5
# 1                 ABHISHEK           7
# 2             ADITI  SINGH           5
# 3           ADITYA  MANKAR           7
# 4             Aman  Pandey           5
# ..                     ...         ...
# 652           VINOD  KUMAR           4
# 653           Akash  Kumar           7
# 654  AVINASH KUMAR JAISWAL          10
# 655           MAYANK  JAIN           8
# 656          ROBIN  SHARMA           7
#
# [657 rows x 2 columns]

# %%
quiz2Grade=pd.merge(st,qz2,left_on='studentname',right_on='Firstname')

# %%
quiz2Grade
# Out:
#            studentname          Firstname Grade/10.00
# 0        AAYUSH  TYAGI      AAYUSH  TYAGI          10
# 1             ABHISHEK           ABHISHEK          10
# 2         ADITI  SINGH       ADITI  SINGH           9
# 3       ADITYA  MANKAR     ADITYA  MANKAR           8
# 4         Aman  Pandey       Aman  Pandey          10
# ..                 ...                ...         ...
# 671       MAYANK  JAIN       MAYANK  JAIN          10
# 672      PARTH  SHUKLA      PARTH  SHUKLA           2
# 673      ROBIN  SHARMA      ROBIN  SHARMA           7
# 674   SHREYANSH  KUMAR   SHREYANSH  KUMAR           6
# 675  SWARNIM  TRIPATHI  SWARNIM  TRIPATHI           8
#
# [676 rows x 3 columns]

# %%
quiz2Grade=quiz2Grade.drop(columns=['Firstname'])

# %%
quiz1Drade
# Out:
#                studentname Grade/10.00
# 0            AAYUSH  TYAGI           5
# 1                 ABHISHEK           7
# 2             ADITI  SINGH           5
# 3           ADITYA  MANKAR           7
# 4             Aman  Pandey           5
# ..                     ...         ...
# 652           VINOD  KUMAR           4
# 653           Akash  Kumar           7
# 654  AVINASH KUMAR JAISWAL          10
# 655           MAYANK  JAIN           8
# 656          ROBIN  SHARMA           7
#
# [657 rows x 2 columns]

# %%
# grades = []
# for row in quiz1Drade['Grade/10.00']:
#     if row < 5:    grades.append('lessthan50')
#     else:           grades.append('Failed')
# quiz1Drade['grades'] = grades

# %%
df['GRADES'] = quiz1Drade['Grade/10.00'].apply(lambda x: 'Less then 50' if x <= 5 else 'False')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-51534cad8cdd> in <module>
# ----> 1 df['GRADES'] = quiz1Drade['Grade/10.00'].apply(lambda x: 'Less then 50' if x <= 5 else 'False')
#
# c:\users\ankit\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-51534cad8cdd> in <lambda>(x)
# ----> 1 df['GRADES'] = quiz1Drade['Grade/10.00'].apply(lambda x: 'Less then 50' if x <= 5 else 'False')
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
quiz1Drade['Grade/10.00']
# Out:
# 0       5
# 1       7
# 2       5
# 3       7
# 4       5
#        ..
# 652     4
# 653     7
# 654    10
# 655     8
# 656     7
# Name: Grade/10.00, Length: 657, dtype: object

# %%
#quiz1Drade['Grade/10.00']=quiz1Drade['Grade/10.00'].apply(pd.to_numeric,downcast='integer')

# %%
quiz1Drade['Grade/10.00']= quiz1Drade['Grade/10.00'].apply(pd.to_numeric,errors="coerce")

# %%
#quiz1Drade['Grade/10.00']
quiz1Drade.dtypes
# Out:
# studentname     object
# Grade/10.00    float64
# dtype: object

# %%
quiz1Drade['Grade/10.00'].isnull().sum()
print(a)
quiz1Drade['Grade/10.00']=quiz1Drade['Grade/10.00'].fillna(0)
# Out:
# 1

# %%
quiz1Drade['Grade/10.00']
# Out:
# 0       5.0
# 1       7.0
# 2       5.0
# 3       7.0
# 4       5.0
#        ...
# 652     4.0
# 653     7.0
# 654    10.0
# 655     8.0
# 656     7.0
# Name: Grade/10.00, Length: 657, dtype: float64

# %%
quiz1Drade['Grade/10.00']=quiz1Drade['Grade/10.00'].astype(int)

# %%
quiz1Drade.dtypes
# Out:
# studentname    object
# Grade/10.00     int32
# dtype: object

# %%
grades = []
for row in quiz1Drade['Grade/10.00']:
        if row > 9:    grades.append('A')
        elif row > 8:  grades.append('A-')
        elif row > 7:  grades.append('B')
        elif row > 6:  grades.append('B-')
        elif row > 5:  grades.append('C')
        elif row > 4:  grades.append('C-')
        elif row > 3:  grades.append('D')
        elif row > 2:  grades.append('D-')
        else:           grades.append('Failed')
quiz1Drade['grades'] = grades
print(quiz1Drade)
# Out:
#                studentname  Grade/10.00 grades
# 0            AAYUSH  TYAGI            5     C-
# 1                 ABHISHEK            7     B-
# 2             ADITI  SINGH            5     C-
# 3           ADITYA  MANKAR            7     B-
# 4             Aman  Pandey            5     C-
# ..                     ...          ...    ...
# 652           VINOD  KUMAR            4      D
# 653           Akash  Kumar            7     B-
# 654  AVINASH KUMAR JAISWAL           10      A
# 655           MAYANK  JAIN            8      B
# 656          ROBIN  SHARMA            7     B-
#
# [657 rows x 3 columns]

# %%
quiz2Grade['Grade/10.00'].isnull().sum()
# Out:
# 0

# %%
quiz2Grade['Grade/10.00']= quiz2Grade['Grade/10.00'].apply(pd.to_numeric,errors="coerce")

# %%
quiz2Grade['Grade/10.00'].isnull().sum()
print(a)
quiz2Grade['Grade/10.00']=quiz2Grade['Grade/10.00'].fillna(0)
# Out:
# 1

# %%
quiz2Grade['Grade/10.00']=quiz2Grade['Grade/10.00'].astype(int)

# %%
quiz1Drade['Grade/10.00'].isnull().sum()
quiz1Drade['Grade/10.00']=quiz1Drade['Grade/10.00'].astype(int)

# %%
grades = []
for row in quiz2Grade['Grade/10.00']:
        if row > 9:    grades.append('A')
        elif row > 8:  grades.append('A-')
        elif row > 7:  grades.append('B')
        elif row > 6:  grades.append('B-')
        elif row > 5:  grades.append('C')
        elif row > 4:  grades.append('C-')
        elif row > 3:  grades.append('D')
        elif row > 2:  grades.append('D-')
        else:           grades.append('Failed')
quiz2Grade['grades'] = grades
print(quiz2Grade)
# Out:
#            studentname  Grade/10.00  grades
# 0        AAYUSH  TYAGI           10       A
# 1             ABHISHEK           10       A
# 2         ADITI  SINGH            9      A-
# 3       ADITYA  MANKAR            8       B
# 4         Aman  Pandey           10       A
# ..                 ...          ...     ...
# 671       MAYANK  JAIN           10       A
# 672      PARTH  SHUKLA            2  Failed
# 673      ROBIN  SHARMA            7      B-
# 674   SHREYANSH  KUMAR            6       C
# 675  SWARNIM  TRIPATHI            8       B
#
# [676 rows x 3 columns]

# %%
quiz2Grade.to_csv("quiz2Grade.csv")
